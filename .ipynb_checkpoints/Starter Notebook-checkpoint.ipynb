# %%
import pandas as pd

def import_data():
    X_train = pd.read_csv('./train/X_train.csv')
    X_test = pd.read_csv('./test/X_test.csv')
    y_train = pd.read_csv('./train/y_train.csv')
    y_test = pd.read_csv('./test/y_test.csv')
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = import_data()

# %%
X_train.shape
# Out:
# (3794, 29)

# %%
X_train.head(10)
# Out:
#      id                 name        first        last     sex date_of_birth  \
# 0  2677  nicholas staggewise     nicholas  staggewise    Male    1994-02-28
# 1   548         newton smith       newton       smith    Male    1995-01-28
# 2  4483       terrance irvin     terrance       irvin    Male    1984-04-10
# 3  9476      jaimie peterson       jaimie    peterson  Female    1986-01-02
# 4   199      ritesh sukhlall       ritesh    sukhlall    Male    1987-05-12
# 5  6134    christopher jones  christopher       jones    Male    1983-08-04
# 6    56        kiante slocum       kiante      slocum  Female    1994-08-17
# 7  6337         john coleman         john     coleman    Male    1964-08-14
# 8   489         michael rosa      michael        rosa    Male    1988-04-15
# 9  4328      lynval chambers       lynval    chambers    Male    1993-01-30
#
#    age        age_group              race  juv_fel_count  ...  \
# 0   22     Less than 25         Caucasian              0  ...
# 1   21     Less than 25  African-American              0  ...
# 2   32          25 - 45  African-American              0  ...
# 3   30          25 - 45  African-American              0  ...
# 4   28          25 - 45         Caucasian              0  ...
# 5   32          25 - 45  African-American              0  ...
# 6   21     Less than 25  African-American              0  ...
# 7   51  Greater than 45  African-American              0  ...
# 8   28          25 - 45         Caucasian              0  ...
# 9   23     Less than 25  African-American              0  ...
#
#                     c_charge_desc   r_jail_in  r_jail_out  type_of_assessment  \
# 0           arrest case no charge         NaN         NaN  Risk of Recidivism
# 1   Grand Theft in the 3rd Degree         NaN         NaN  Risk of Recidivism
# 2   Grand Theft in the 3rd Degree  2013-12-21  2014-02-21  Risk of Recidivism
# 3  Felony Driving While Lic Suspd         NaN         NaN  Risk of Recidivism
# 4           arrest case no charge         NaN         NaN  Risk of Recidivism
# 5               Robbery W/Firearm         NaN         NaN  Risk of Recidivism
# 6           arrest case no charge         NaN         NaN  Risk of Recidivism
# 7           arrest case no charge         NaN         NaN  Risk of Recidivism
# 8                         Battery         NaN         NaN  Risk of Recidivism
# 9   Grand Theft in the 3rd Degree  2014-02-01  2014-02-06  Risk of Recidivism
#
#   screening_date v_type_of_assessment v_screening_date  in_custody  \
# 0     2013-09-24     Risk of Violence       2013-09-24  2013-09-23
# 1     2013-06-17     Risk of Violence       2013-06-17  2013-06-16
# 2     2013-10-12     Risk of Violence       2013-10-12  2013-10-11
# 3     2014-01-12     Risk of Violence       2014-01-12  2014-01-11
# 4     2013-08-29     Risk of Violence       2013-08-29         NaN
# 5     2013-09-30     Risk of Violence       2013-09-30  2013-08-02
# 6     2013-08-24     Risk of Violence       2013-08-24  2015-01-30
# 7     2014-02-04     Risk of Violence       2014-02-04  2015-07-27
# 8     2013-10-04     Risk of Violence       2013-10-04  2013-10-04
# 9     2013-04-24     Risk of Violence       2013-04-24  2013-05-15
#
#   out_custody start
# 0  2013-09-27     3
# 1  2013-06-16     0
# 2  2013-10-15     3
# 3  2014-01-12     0
# 4         NaN     0
# 5  2013-09-28     0
# 6  2015-01-31    79
# 7  2015-09-10     0
# 8  2013-10-05     1
# 9  2013-06-22     1
#
# [10 rows x 29 columns]
